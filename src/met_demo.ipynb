# %%
import cequalw2 as w2

# %%
df = w2.read_met('/Users/todd/GitHub/ecohydrology/CE-QUAL-W2/examples_precomputed/Detroit Reservoir/InputFiles/metDetroit2002.csv', 2002)
# Out:
# file_type: FileType.CSV

# %%
w2.multi_plot(df, figsize=(5, 10), fontsize=6, )
